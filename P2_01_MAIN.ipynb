# %% [markdown]
# #TITRE

# %% [markdown]
# ## Préambule
#
# Je suis Data Scientist dans une start-up de la EdTech, nommée academy, qui propose des contenus de formation en ligne pour un public de niveau lycée et université.
#
# Mark, mon manager, m'a convié à une réunion pour me présenter le projet d’expansion à l’international de l’entreprise. Il me confie une première mission d’analyse exploratoire, pour déterminer si les données sur l’éducation de la banque mondiale permettent d’informer le projet d’expansion.
#
# Voici les différentes questions que Mark aimerait explorer, que j'ai notées durant la réunion :
#
# Quels sont les pays avec un fort potentiel de clients pour nos services ? Pour chacun de ces pays, quelle sera l’évolution de ce potentiel de clients ? Dans quels pays l'entreprise doit-elle opérer en priorité ?
#
# Pour cela on a accès à un jeu de données décrivant l’accès à l’éducation, l’obtention de diplômes et des informations relatives aux professeurs, aux dépenses liées à l’éducation...
#
#
# On va donc analyser chaque fichier disponible pour en tirer des conclusions.
#
# ## Analyse des données
#
# La configuration de l'ordinateur pour ce projet est le suivant :
#
# Intel Core i5 8 GB de RAM Disque de 1 To

# %% [markdown]
# Les lignes suivantes vont permettre de rappeler les versions de Python et des librairies utilisées dans NoteBook.

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
print('version matplotlib:', importlib.metadata.version('matplotlib'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-85ac60e3007f> in <module>()
# ----> 1 print('version matplotlib:', importlib.metadata.version('matplotlib'))
#
# NameError: name 'importlib' is not defined

# %%
statistics
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-91145c65e518> in <module>()
# ----> 1 statistics
#
# NameError: name 'statistics' is not defined

# %% [markdown]
# Pour rappel NumPy est destinée à manipuler des matrices ou tableaux multidimensionnels ainsi que des fonctions mathématiques opérant sur ces tableaux.

# %% [markdown]
# Pour commencer on va analyser le premier <A HREF="./P2_02_Analyse_EdCountry.ipynb"> fichier EdCountry</A> dans lequel on va regarder des données sur une liste de pays.
#
#
#
# Ce premier fichier permet de conclure que les régions à plus hauts revenus et correspondant le plus à notre projet sont l'Europe et l'Amérique du Nord. Cependant certains pays de l'Amérique Latine, du Moyen Orient ainsi que des pays de la zone Pacifique ont aussi un niveau de revenu élevé.

# %% [markdown]
# On s'intéresse ensuite à l'analyse du  <A HREF="./P2_03_Analyse_CountrySeries.ipynb">fichier EdCountrySeries</A>
#
#
#
# Ce fichier permet de conclure que les données concernant les pays qui nous intéressent viennent de sources gouvernementales et de sources comme Eurostat qui possèdent des informations solides, on peut donc considérer que les données observées lors de l'analyse du fichier EdStatsCountry sont solides et utilisables pour notre étude de cas.

# %% [markdown]
# On s'intéresse ensuite à l'analyse du <A HREF="./P2_04_Analyse_EdData.ipynb">fichier EdStatsData</A>  affichant des données très intéressantes sur les statistiques scolaires des pays à haut revenus qu'on a repéré dans l'analyse du fichier "EdStatsCountry.csv".
#
# On peut établir à partir de toutes nos données ci-dessus que les statistiques obtenus via la fonction describe sont utilisables.
# L'écart-type est relativement faible et la médiane a une valeur proche de la moyenne. On en conclut donc qu'il n'y a pas une dispersion importante de nos valeurs sur le pourcentages d'élèves à l'université et le nombre d'années de scolarité pour les pays à haut revenus étudiés ici.
#
#
# A partir des données scolaires de l'année 2020 et des prévisions pour l'année 2025, on a la confirmation que l'Europe et les pays d'Amérique du Nord sont d'excellents candidats. Comme dit précedemment, des pays comme Aruba, le Bahrein et l'Arabie Saoudite sont des pays à potentiel intéressant pour déployer notre formation.

# %% [markdown]
# On s'intéresse ensuite à l'analyse du <A HREF="./P2_05_Analyse_EdFootNote.ipynb">fichier EdFootNote</A>.
#
#
# Ce fichier permet de conclure clairement que pour les années 2020 et 2025, des données sont manquantes. Ce qui n'est pas le cas pour d'autres années entre 1980 et 2017. Ces données proviennent de sources fiables comme l'UNESCO, organisation mondiale de protection des patrimoines, ainsi que de sources gouvernementales. Il faudrait donc penser à demander des détails(exemple : régions ou fédérations incluses dans les statistiques) pour les années allant entre 2020 et 2025.

# %% [markdown]
# Pour finir, on analyse  <A HREF="./P2_06_Analyse_EdStatSeries.ipynb">le fichier StatSeries</A> .
#
# Le site <A HREF="http://www.barrolee.com/">Barrolee</A> contient une base de données sur les populations sur les sexes par des intervales d'écart de 5 ans entre 1950 et 2010. On conclut via ce fichier que nous possédons donc bien des sources fiables pour notre étude de cas mais que nos listes sont incomplètes. Par exemple, on possède la description de certaines données sans avoir la valeur de ces données.

# %% [markdown]
# # Conclusion et perspectives
#
# L'étude de nos fichiers permet de conclure que le déploiement de la formation pourrait se faire principalement en Europe et en Amérique du Nord. C'est dans ces pays que l'on possède le plus de données et le plus de fiabilité concernant les statistiques. Il est cependant intéressant de regarder certains pays comme l'Australie ou encore l'Arabie Saoudite ayant des richesses et un niveau d'éducation répondant à nos critères. Le déploiement de la formation étant imminent et à moyen terme, on s'est donc basé sur l'année 2020 et la projection de l'année 2025 pour arriver à ce raisonnement.
#
# Pour finir, il faut rappeler que beaucoup d'informations sont manquantes dans les bases de données qui nous ont été fournies initialement. todo demander des updates aux organismes qui fournissent ces bases de données ou bien trouver d'autres sources d'informations complémentaires pour améliorer nos recherches.
#
# On a supposé dans cette étude que l'on pourrait traduire nos cours en Anglais rapidement.Si ce n'est pas le cas, on peut modifier légèrement l'étude et se restreindre à la francophonie, on peut donc s'intéresser aux pays avec les taux les plus élevés d'étudiants francophones.
