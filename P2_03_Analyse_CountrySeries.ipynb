# %% [markdown]
# # Analyse du fichier EdStatsCountry-Series.csv

# %% [markdown]
# On observe qu'il y a intialement 613 lignes et 4 colonnes.

# %% [markdown]
# Version Google Colab

# %%
#import pandas as pd
#import matplotlib.pyplot as plt
#import pandas as pd
#use_colab=True
#if use_colab:
  #from google.colab import drive
  #drive.mount('/content/drive')
#df = pd.read_csv ('/content/drive/MyDrive/Projet OpenClassrooms/Projet+Python_Dataset_Edstats_csv/EdStatsCountry-Series.csv') 
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None) #affichage de toutes les lignes
#pd.set_option('max_colwidth', 300)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Version Notebook

# %%
df = pd.read_csv ('EdStatsCountry-Series.csv')

# %% [markdown]
# On a pas de doublons dans ce DataFrame

# %%
df1=df
doublon = df1.duplicated()
DoublonCalc=len(df1)-len(df1.drop_duplicates())
print(DoublonCalc)
# Out:
# 0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613 entries, 0 to 612
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountryCode  613 non-null    object
#  1   SeriesCode   613 non-null    object
#  2   DESCRIPTION  613 non-null    object
#  3   Unnamed: 3   0 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 19.3+ KB

# %%
df1.isnull().any()
# Out:
# CountryCode    False
# SeriesCode     False
# DESCRIPTION    False
# Unnamed: 3      True
# dtype: bool

# %%
df1.drop('Unnamed: 3',1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
df1.isnull().sum()
# Out:
# CountryCode    0
# SeriesCode     0
# DESCRIPTION    0
# dtype: int64

# %% [markdown]
# On s'intéresse à la colonne "Description" pour voir si on peut trouver des données pouvant nous intéresser.

# %%
Tableau=df1[["CountryCode", "DESCRIPTION"]]
Tableau.sort_values(by=['DESCRIPTION'])
# Out:
#     CountryCode  \
# 588         VEN
# 557         TZA
# 559         TZA
# 561         TZA
# 563         TZA
# 564         TZA
# 565         TZA
# 119         CYP
# 129         CYP
# 128         CYP
# 126         CYP
# 123         CYP
# 122         CYP
# 32          AUS
# 64          BMU
# 229         HKG
# 253         ISR
# 233         HRV
# 463         SGP
# 403         NLD
# 451         ROU
# 130         CZE
# 450         ROU
# 437         PRT
# 82          CHE
# 83          CHE
# 436         PRT
# 425         POL
# 424         POL
# 405         NOR
# 358         MLT
# 131         CZE
# 359         MLT
# 404         NOR
# 132         DEU
# 306         LTU
# 138         DNK
# 210         GRC
# 211         GRC
# 236         HUN
# 237         HUN
# 244         IRL
# 245         IRL
# 250         ISL
# 251         ISL
# 179         GBR
# 254         ITA
# 255         ITA
# 163         FIN
# 162         FIN
# 159         EST
# 158         EST
# 157         ESP
# 156         ESP
# ...

# %% [markdown]
# En se basant sur le premier fichier,on va s'intéresser à différents pays ayant un haut revenu. On ne pourra pas voir tout les pays par contrainte de temps, mais on pourra se faire une première idée du déploiement de la formation.

# %%
n=10
for i in range(n):
    list = input("Enter string:")
    pd.set_option('display.max_rows', None) 
    pd.set_option('max_colwidth', 300)
    Tab1=Tableau[Tableau['CountryCode'].str.contains(list)]
    display(Tab1)
# Out:
# Enter string:ARE
#    CountryCode                                               DESCRIPTION
# 16         ARE   Data sources: United Nations World Population Prospects
# 17         ARE  Data sources : United Nations World Population Prospects
# Enter string:ABW
#   CountryCode                                               DESCRIPTION
# 0         ABW  Data sources : United Nations World Population Prospects
# 1         ABW   Data sources: United Nations World Population Prospects
# Enter string:AUT
#    CountryCode              DESCRIPTION
# 38         AUT  Data sources : Eurostat
# 39         AUT  Data sources : Eurostat
# Enter string:AUS
#    CountryCode  \
# 32         AUS
# 33         AUS
# 34         AUS
# 35         AUS
# 36         AUS
# 37         AUS
#
#                                                                                                         DESCRIPTION
# ...

# %% [markdown]
# Indications et précisions :
#
# <A HREF="https://en.wikipedia.org/wiki/Eurostat">Eurostat</A> est une comission chargée de l'information statistique.
#
# <A HREF="https://population.un.org/wpp/">United Nations World Population Prospects</A>  est un organisme chargé de la prédiction future des populations mondiales.
# On en conclut ici que les sources de données sont plutot fiables et viennent principalement de sources gouvernementales.

# %% [markdown]
# Conclusion:  On peut observer que les données viennent de sources fiables et gouvernementales avec des exemples mentionnés ci-dessus. On dispose donc d'informations solides.
